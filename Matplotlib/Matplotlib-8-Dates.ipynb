# %%
import pandas as pd
from datetime import datetime, timedelta
from matplotlib import pyplot as plt
from matplotlib import dates as mpl_dates

plt.style.use('seaborn')

dates = [
    datetime(2019, 5, 24),
    datetime(2019, 5, 25),
    datetime(2019, 5, 26),
    datetime(2019, 5, 27),
    datetime(2019, 5, 28),
    datetime(2019, 5, 29),
    datetime(2019, 5, 30)
]

y = [0, 1, 3, 4, 6, 5, 7]


plt.plot_date(dates, y)

plt.tight_layout()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.plot_date(dates, y, linestyle='solid', marker=None)

plt.tight_layout()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# autoformatxdate method en mi figura
# rotar los datos para que se vean mejor
# Obtener la figura
# get current figure
plt.plot_date(dates, y, linestyle='solid', marker=None)

plt.gcf().autofmt_xdate()

plt.tight_layout()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# cambiar el formato de las fechas
# https://docs.python.org/3/library/datetime.html#strftime-and-strptime-behavior
date_format = mpl_dates.DateFormatter('%b, %d, %Y')

# establecerlo como el formato del ejex
plt.gca().xaxis.set_major_formatter(date_format)

plt.plot_date(dates, y, linestyle='solid', marker=None)

plt.gcf().autofmt_xdate()

plt.tight_layout()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
df = pd.read_csv('dates.csv')
df
# Out:
#           Date         Open         High          Low        Close  \
# 0   2019-05-18  7266.080078  8281.660156  7257.259766  8193.139648
# 1   2019-05-19  8193.139648  8193.139648  7591.850098  7998.290039
# 2   2019-05-20  7998.290039  8102.319824  7807.770020  7947.930176
# 3   2019-05-21  7947.930176  8033.759766  7533.660156  7626.890137
# 4   2019-05-22  7626.890137  7971.259766  7478.740234  7876.500000
# 5   2019-05-23  7876.500000  8165.450195  7801.569824  7996.399902
# 6   2019-05-24  7996.399902  8140.819824  7948.680176  8059.129883
# 7   2019-05-25  8059.129883  8779.000000  7894.529785  8726.230469
# 8   2019-05-26  8726.230469  8931.530273  8668.459961  8785.169922
# 9   2019-05-27  8785.169922  8818.709961  8562.200195  8718.849609
# 10  2019-05-28  8718.849609  8760.480469  8444.099609  8664.559570
# 11  2019-05-29  8664.559570  9065.889648  8027.209961  8276.250000
# 12  2019-05-30  8276.250000  8570.780273  8116.000000  8560.080078
# ...

# %%
close_prices = df['Close']
dates = df['Date']
plt.style.use('seaborn-notebook')

plt.plot_date(dates, close_prices, linestyle='solid')

plt.gcf().autofmt_xdate()

plt.title('Bitcoin Close Price (USD)')
plt.xlabel('Date')
plt.ylabel('Price')

plt.tight_layout()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# pandas lee las fechas como strings
# objects representan los strings
df['Date']
# Out:
# 0     2019-05-18
# 1     2019-05-19
# 2     2019-05-20
# 3     2019-05-21
# 4     2019-05-22
# 5     2019-05-23
# 6     2019-05-24
# 7     2019-05-25
# 8     2019-05-26
# 9     2019-05-27
# 10    2019-05-28
# 11    2019-05-29
# 12    2019-05-30
# 13    2019-05-31
# 14    2019-05-17
# Name: Date, dtype: object

# %%
# se puede observar que la última fecha sigue de último y se pasaría ese orden como tal al gráfico
pd.to_datetime(df['Date'])
# Out:
# 0    2019-05-18
# 1    2019-05-19
# 2    2019-05-20
# 3    2019-05-21
# 4    2019-05-22
# 5    2019-05-23
# 6    2019-05-24
# 7    2019-05-25
# 8    2019-05-26
# 9    2019-05-27
# 10   2019-05-28
# 11   2019-05-29
# 12   2019-05-30
# 13   2019-05-31
# 14   2019-05-17
# Name: Date, dtype: datetime64[ns]

# %%
df['Date'] = pd.to_datetime(df['Date'])

# %% [markdown]
# Se puede organizar el dataframe entero con base en una columna usando el método `sort_values`.
# > Se pasa el nombre de la columna como primer parámetro

# %%
df.sort_values('Date', inplace=True) 
df
# Out:
#          Date         Open         High          Low        Close  \
# 14 2019-05-17  7566.080078  7281.690156  7257.259766  8193.139648
# 0  2019-05-18  7266.080078  8281.660156  7257.259766  8193.139648
# 1  2019-05-19  8193.139648  8193.139648  7591.850098  7998.290039
# 2  2019-05-20  7998.290039  8102.319824  7807.770020  7947.930176
# 3  2019-05-21  7947.930176  8033.759766  7533.660156  7626.890137
# 4  2019-05-22  7626.890137  7971.259766  7478.740234  7876.500000
# 5  2019-05-23  7876.500000  8165.450195  7801.569824  7996.399902
# 6  2019-05-24  7996.399902  8140.819824  7948.680176  8059.129883
# 7  2019-05-25  8059.129883  8779.000000  7894.529785  8726.230469
# 8  2019-05-26  8726.230469  8931.530273  8668.459961  8785.169922
# 9  2019-05-27  8785.169922  8818.709961  8562.200195  8718.849609
# 10 2019-05-28  8718.849609  8760.480469  8444.099609  8664.559570
# 11 2019-05-29  8664.559570  9065.889648  8027.209961  8276.250000
# ...

# %%
close_prices = df['Close']
dates = df['Date']
plt.style.use('seaborn')

plt.plot_date(dates, close_prices, linestyle='solid')

plt.gcf().autofmt_xdate()

plt.title('Bitcoin Prices (USD)')
plt.xlabel('Date')
plt.ylabel('Closing Price')

plt.tight_layout()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
